# %%
using PyPlot
using LaTeXStrings
using DelimitedFiles

# %%
# give the directory where the data from all the runs are saved
your_dir = "/home/thanasis/repos/BondiToy/examples/run00"
# Out:
# "/home/thanasis/repos/BondiToy/examples/run00"

# %%
# homogeneous WH model
dir = your_dir*"/WH_noise_B0_norms_0.125"

# tf is the time until which we compute the exact convergence ratio for this case
tf = 14

#N=0 & N=1 
Lop_0_c0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,2]
Lop_1_c0 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
B0_t_0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,1]
B0_Conv_0   = similar(B0_t_0)
for i in 1:1:length(B0_Conv_0)
    i0 = i
    i1 = (i0-1)*2 +1    
    B0_Conv_0[i0] = log2.(Lop_0_c0[i0]/Lop_1_c0[i1])
end

#N=1 & N=2 
Lop_1_c1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
Lop_2_c1 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
B0_t_1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,1]
B0_Conv_1   = similar(B0_t_1)
for i in 1:1:length(B0_Conv_1)
    i0 = i
    i1 = (i0-1)*2 +1    
    B0_Conv_1[i0] = log2.(Lop_1_c1[i0]/Lop_2_c1[i1])
end

#N=2 & N=3 
Lop_2_c2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
Lop_3_c2 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
B0_t_2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,1]
B0_Conv_2   = similar(B0_t_2)
for i in 1:1:length(B0_Conv_2)
    i0 = i
    i1 = (i0-1)*2 +1    
    B0_Conv_2[i0] = log2.(Lop_2_c2[i0]/Lop_3_c2[i1])
end

#N=3 & N=4 
Lop_3_c3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
Lop_4_c3 = readdlm(dir*"/data_257_256/Lopside_norm.dat", comments=true)[:,2]
B0_t_3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,1]
B0_Conv_3   = similar(B0_t_3)
for i in 1:1:length(B0_Conv_3)
    i0 = i
    i1 = (i0-1)*2 +1    
    B0_Conv_3[i0] = log2.(Lop_3_c3[i0]/Lop_4_c3[i1])
end

# %%
# inhomogeneous WH model B1
dir = your_dir*"/WH_noise_B1_norms_0.125"

#N=0 & N=1 
Lop_0_c0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,2]
Lop_1_c0 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
B1_Conv_0   = similar(B0_t_0)
for i in 1:1:length(B0_t_0)
    i0 = i
    i1 = (i0-1)*2 +1    
    B1_Conv_0[i0] = log2.(Lop_0_c0[i0]/Lop_1_c0[i1])
end

#N=1 & N=2 
Lop_1_c1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
Lop_2_c1 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
B1_Conv_1   = similar(B0_t_1)
for i in 1:1:length(B0_t_1)
    i0 = i
    i1 = (i0-1)*2 +1    
    B1_Conv_1[i0] = log2.(Lop_1_c1[i0]/Lop_2_c1[i1])
end

#N=2 & N=3 
Lop_2_c2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
Lop_3_c2 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
B1_Conv_2   = similar(B0_t_2)
for i in 1:1:length(B0_t_2)
    i0 = i
    i1 = (i0-1)*2 +1    
    B1_Conv_2[i0] = log2.(Lop_2_c2[i0]/Lop_3_c2[i1])
end

#N=3 & N=4 
Lop_3_c3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
Lop_4_c3 = readdlm(dir*"/data_257_256/Lopside_norm.dat", comments=true)[:,2]
B1_Conv_3   = similar(B0_t_3)
for i in 1:1:length(B0_t_3)
    i0 = i
    i1 = (i0-1)*2 +1    
    B1_Conv_3[i0] = log2.(Lop_3_c3[i0]/Lop_4_c3[i1])
end

# %%
# inhomogeneous WH model B2
dir = your_dir*"/WH_noise_B2_norms_0.125"

#N=0 & N=1 
Lop_0_c0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,2]
Lop_1_c0 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
B2_Conv_0   = similar(B0_t_0)
for i in 1:1:length(B0_t_0)
    i0 = i
    i1 = (i0-1)*2 +1    
    B2_Conv_0[i0] = log2.(Lop_0_c0[i0]/Lop_1_c0[i1])
end

#N=1 & N=2 
Lop_1_c1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
Lop_2_c1 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
B2_Conv_1   = similar(B0_t_1)
for i in 1:1:length(B0_t_1)
    i0 = i
    i1 = (i0-1)*2 +1    
    B2_Conv_1[i0] = log2.(Lop_1_c1[i0]/Lop_2_c1[i1])
end

#N=2 & N=3 
Lop_2_c2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
Lop_3_c2 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
B2_Conv_2   = similar(B0_t_2)
for i in 1:1:length(B0_t_2)
    i0 = i
    i1 = (i0-1)*2 +1    
    B2_Conv_2[i0] = log2.(Lop_2_c2[i0]/Lop_3_c2[i1])
end

#N=3 & N=4 
Lop_3_c3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
Lop_4_c3 = readdlm(dir*"/data_257_256/Lopside_norm.dat", comments=true)[:,2]
B2_Conv_3   = similar(B0_t_3)
for i in 1:1:length(B0_t_3)
    i0 = i
    i1 = (i0-1)*2 +1    
    B2_Conv_3[i0] = log2.(Lop_3_c3[i0]/Lop_4_c3[i1])
end

# %%
# inhomogeneous WH model B3
dir = your_dir*"/WH_noise_B3_norms_0.125"

#N=0 & N=1 
Lop_0_c0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,2]
Lop_1_c0 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
B3_t_0 = readdlm(dir*"/data_17_16/Lopside_norm.dat", comments=true)[:,1]
B3_Conv_0   = similar(B3_t_0)
for i in 1:1:length(B3_Conv_0)
    i0 = i
    i1 = (i0-1)*2 +1    
    B3_Conv_0[i0] = log2.(Lop_0_c0[i0]/Lop_1_c0[i1])
end

#N=1 & N=2 
Lop_1_c1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,2]
Lop_2_c1 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
B3_t_1 = readdlm(dir*"/data_33_32/Lopside_norm.dat", comments=true)[:,1]
B3_Conv_1   = similar(B3_t_1)
for i in 1:1:length(B3_Conv_1)
    i0 = i
    i1 = (i0-1)*2 +1    
    B3_Conv_1[i0] = log2.(Lop_1_c1[i0]/Lop_2_c1[i1])
end

#N=2 & N=3 
Lop_2_c2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,2]
Lop_3_c2 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
B3_t_2 = readdlm(dir*"/data_65_64/Lopside_norm.dat", comments=true)[:,1]
B3_Conv_2   = similar(B3_t_2)
for i in 1:1:length(B3_Conv_2)
    i0 = i
    i1 = (i0-1)*2 +1    
    B3_Conv_2[i0] = log2.(Lop_2_c2[i0]/Lop_3_c2[i1])
end

#N=3 & N=4 
Lop_3_c3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,2]
Lop_4_c3 = readdlm(dir*"/data_257_256/Lopside_norm.dat", comments=true)[:,2]
B3_t_3 = readdlm(dir*"/data_129_128/Lopside_norm.dat", comments=true)[:,1]
B3_Conv_3   = similar(B3_t_3)
for i in 1:1:length(B3_Conv_3)
    i0 = i
    i1 = (i0-1)*2 +1    
    B3_Conv_3[i0] = log2.(Lop_3_c3[i0]/Lop_4_c3[i1])
end

# %%
## PLOT ##

fig = figure("pyplot_subplot_touching",figsize=(17,6.5))
subplots_adjust(hspace=0.1, wspace=0.1, top = 0.99, bottom = 0.05, right=0.98, left=0.07)# Set the vertical spacing between axes
#subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
#            hspace = 0, wspace = 0)

# homogeneous
subplot(411) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,14.0) # Set the x-limits
xticks(0.0:2:14.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}",fontsize="20")
yticks(1.:1.0:3.,fontsize="15") # Set the y-tick range and step size
ylim(0.5,3.5) # Set the y-limits
#plot
plot(B0_t_0, B0_Conv_0, linestyle=":" , linewidth=3,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||\,/\,||\mathbf{u}_{h_1}||\right)}")
plot(B0_t_1, B0_Conv_1, linestyle="-.", linewidth=2.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||\,/\,||\mathbf{u}_{h_2}||\right)}")
plot(B0_t_2, B0_Conv_2, linestyle="--", linewidth=2.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||\,/ \,||\mathbf{u}_{h_3}||\right)}")
plot(B0_t_3, B0_Conv_3, linestyle="-" , linewidth=2.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||\,/ \,||\mathbf{u}_{h_4}||\right)}")

##########################
# B1
subplot(412) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,14.0) # Set the x-limits
xticks(0.0:2:14.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}",fontsize="20")
yticks(1.:1.0:3.,fontsize="15") # Set the y-tick range and step size
ylim(0.5,3.5) # Set the y-limits
#plot
plot(B0_t_0, B1_Conv_0, linestyle=":" , linewidth=3,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||\,/\,||\mathbf{u}_{h_1}||\right)}")
plot(B0_t_1, B1_Conv_1, linestyle="-.", linewidth=2.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||\,/\,||\mathbf{u}_{h_2}||\right)}")
plot(B0_t_2, B1_Conv_2, linestyle="--", linewidth=2.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||\,/ \,||\mathbf{u}_{h_3}||\right)}")
plot(B0_t_3, B1_Conv_3, linestyle="-" , linewidth=2.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||\,/ \,||\mathbf{u}_{h_4}||\right)}")

legend(fontsize="15")

##########################
# B2
subplot(413) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,14.0) # Set the x-limits
xticks(0.0:2:14.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}",fontsize="20")
yticks(1.:1.0:3.,fontsize="15") # Set the y-tick range and step size
ylim(0.5,3.5) # Set the y-limits
#plot
plot(B0_t_0, B2_Conv_0, linestyle=":" , linewidth=3,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||\,/\,||\mathbf{u}_{h_1}||\right)}")
plot(B0_t_1, B2_Conv_1, linestyle="-.", linewidth=2.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||\,/\,||\mathbf{u}_{h_2}||\right)}")
plot(B0_t_2, B2_Conv_2, linestyle="--", linewidth=2.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||\,/ \,||\mathbf{u}_{h_3}||\right)}")
plot(B0_t_3, B2_Conv_3, linestyle="-" , linewidth=2.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||\,/ \,||\mathbf{u}_{h_4}||\right)}")

##########################
# B3
subplot(414) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,14.0) # Set the x-limits
xticks(0.0:2:14.0,fontsize="15") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}",fontsize="20")
yticks(1.:1.0:3.,fontsize="15") # Set the y-tick range and step size
ylim(0.5,3.5) # Set the y-limits
#plot
plot(B3_t_0, B3_Conv_0, linestyle=":" , linewidth=3,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||\,/\,||\mathbf{u}_{h_1}||\right)}")
plot(B3_t_1, B3_Conv_1, linestyle="-.", linewidth=2.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||\,/\,||\mathbf{u}_{h_2}||\right)}")
plot(B3_t_2, B3_Conv_2, linestyle="--", linewidth=2.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||\,/ \,||\mathbf{u}_{h_3}||\right)}")
plot(B3_t_3, B3_Conv_3, linestyle="-" , linewidth=2.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||\,/ \,||\mathbf{u}_{h_4}||\right)}")

fig.canvas.draw() # Update the figure
#suptitle("3x1 Shared Axis")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7ff8736fe198>)
